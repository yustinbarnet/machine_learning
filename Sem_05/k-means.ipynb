# %% [markdown]
# # K Means - Generated data
#
# Isotropic dataset module in sklearn [here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html) \
# Train-test splits in sklearn [here](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) \
# k-Means module in sklearn [here](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

# %%
X, _ = make_blobs(n_samples = 400 , n_features= 2, random_state = 1 ) #en el no supervisado y no existe

# Create train (80%) and test (20%) sets and print all shapes
X_train, X_test = train_test_split(X, test_size=0.2, random_state=1)

#creacion del diagrama
_, axes = plt.subplots(1,2, figsize=(8,4))
axes[0].scatter( X[:,0] , X[:,1] , edgecolors='k', c='g')
axes[1].scatter( X_train[:,0], X_train[:,1], edgecolors='k', c='b')
axes[1].scatter( X_test[:,0], X_test[:,1], edgecolors='k', c='r')

# %%
kmeans = KMeans(n_clusters=3,random_state=1)

# Train Kmeans
kmeans.fit(X_train)
# Out:
# KMeans(n_clusters=3, random_state=1)

# %%
# Plot centroids
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[-9.98586251 -3.8181046 ]
#  [-1.51276967  4.35006956]
#  [-7.11846843 -8.22532387]]

# %%
_, ax = plt.subplots (figsize = (5,4))
colors=['blue','cyan','magenta']

# plot data and found centroids
ax.scatter(X_test[:,0], X_test[:,1],c='b',edgecolors='k') #dibujar los puntos
ax.scatter(centroids[:,0],centroids[:,1], s=600,marker='*',edgecolors='k',c='y') #dibujar los centroides

# %%
# Create predictions
predictions = kmeans.predict(X_test)

# %%
_, ax= plt.subplots(figsize=(5,4))
ax.scatter(X_test[:,0], X_test[:,1], c=predictions, edgecolors='k',cmap='Paired')

# %% [markdown]
# # K Means - Real data
#
# Download the fruits data [here](https://drive.google.com/file/d/1M8tiAWDZclABJN1Meq9oEHCLJTNyHdpP/view?usp=share_link)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = pd.read_csv('/content/fruits_data_ext.csv')
numeric_data = data.select_dtypes(include=[np.number])

X = numeric_data.drop(columns=['fruit_label']).values

# %%
# Split train / test data
X_train, X_test = train_test_split(X, test_size=0.2, random_state=1)

# %%
# Train Kmeans
kmeans = KMeans(n_clusters=4, random_state=1)
kmeans.fit(X_train)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %%
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[ 32.66666667 201.06666667   8.06720204   9.43053537   0.76152677]
#  [ 24.7027027  161.87837838   7.52428819   7.82023414   0.8004036 ]
#  [ 24.875      354.625        9.38433528   9.43433528   0.75546676]
#  [ 33.24137931 107.96551724   6.24216658   6.85251141   0.7629704 ]]

# %%
# Predict values
predictions = kmeans.predict(X_test)

# %%
_, axes = plt.subplots(1, 2, figsize=(15, 5))
colors = ['blue', 'cyan', 'magenta']

axes[0].scatter(X_test[:, 0], X_test[:, 1], c=predictions, edgecolors='k', cmap='Paired')
axes[0].set_title('Predicted clusters')
axes[1].scatter(X_test[:, 0], X_test[:, 1], c='b', edgecolors='k')
axes[1].scatter(centroids[:, 0], centroids[:, 1], s=600, marker='*', edgecolors='k', c='y')
axes[1].set_title('Centroids')
# Out:
# Text(0.5, 1.0, 'Centroids')

# %% [markdown]
# # Expanding clustering
#
# Explore K-means using different num of centroids

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

# %%
X, _ = make_blobs(n_samples = 400 , n_features= 2, random_state = 1 ) #en el no supervisado y no existe

# Create train (80%) and test (20%) sets and print all shapes
X_train, X_test = train_test_split(X, test_size=0.2, random_state=1)

#creacion del diagrama
_, axes = plt.subplots(1,2, figsize=(8,4))
axes[0].scatter( X[:,0] , X[:,1] , edgecolors='k', c='g')
axes[1].scatter( X_train[:,0], X_train[:,1], edgecolors='k', c='b')
axes[1].scatter( X_test[:,0], X_test[:,1], edgecolors='k', c='r')

# %%
kmeans = KMeans(n_clusters=4,random_state=1)

# Train Kmeans
kmeans.fit(X_train)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %%
# Plot centroids
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[-10.01034787  -3.78021192]
#  [ -1.51276967   4.35006956]
#  [ -6.41918324  -8.63906161]
#  [ -7.93022468  -7.68912089]]

# %%
_, ax = plt.subplots (figsize = (5,4))
colors=['blue','cyan','magenta']

# plot data and found centroids
ax.scatter(X_test[:,0], X_test[:,1],c='b',edgecolors='k') #dibujar los puntos
ax.scatter(centroids[:,0],centroids[:,1], s=600,marker='*',edgecolors='k',c='y') #dibujar los centroides

# %%
# Create predictions
predictions = kmeans.predict(X_test)

# %%
_, ax= plt.subplots(figsize=(5,4))
ax.scatter(X_test[:,0], X_test[:,1], c=predictions, edgecolors='k',cmap='Paired')
